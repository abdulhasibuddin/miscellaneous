# %%
# Collected from: https://pythonprogramming.net/tensorflow-deep-neural-network-machine-learning-tutorial/

# %%
import tensorflow as tf

# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("/tmp/data/", one_hot = True)
# Out:
# WARNING:tensorflow:From <ipython-input-4-0328e0b4fafb>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From c:\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
n_nodes_hl1 = 100
n_nodes_hl2 = 100
n_nodes_hl3 = 100
n_nodes_hl4 = 100
n_nodes_hl5 = 100
n_nodes_hl6 = 100
n_nodes_hl7 = 100
n_nodes_hl8 = 100
n_nodes_hl9 = 100
n_nodes_hl10 = 100
n_nodes_hl11 = 100

n_classes = 10
batch_size = 100

# %%
x = tf.placeholder('float', [None, 784])
y = tf.placeholder('float')

# %%
# Building Neural Network Model::
def neural_network_model(data):
    hidden_1_layer = {'weights':tf.Variable(tf.random_normal([784, n_nodes_hl1])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl1]))}

    hidden_2_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl1, n_nodes_hl2])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl2]))}

    hidden_3_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl2, n_nodes_hl3])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl3]))}
    
    hidden_4_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl3, n_nodes_hl4])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl4]))}
    
    hidden_5_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl4, n_nodes_hl5])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl5]))}
    
    hidden_6_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl5, n_nodes_hl6])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl6]))}
    
    hidden_7_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl6, n_nodes_hl7])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl7]))}
    
    hidden_8_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl7, n_nodes_hl8])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl8]))}
    
    hidden_9_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl8, n_nodes_hl9])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl9]))}
    
    hidden_10_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl9, n_nodes_hl10])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl10]))}
    
    hidden_11_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl10, n_nodes_hl11])),
                      'biases':tf.Variable(tf.random_normal([n_nodes_hl11]))}

    output_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl11, n_classes])),
                    'biases':tf.Variable(tf.random_normal([n_classes]))}
    
    l1 = tf.add(tf.matmul(data,hidden_1_layer['weights']), hidden_1_layer['biases'])
    l1 = tf.nn.relu(l1)

    l2 = tf.add(tf.matmul(l1,hidden_2_layer['weights']), hidden_2_layer['biases'])
    l2 = tf.nn.relu(l2)

    l3 = tf.add(tf.matmul(l2,hidden_3_layer['weights']), hidden_3_layer['biases'])
    l3 = tf.nn.relu(l3)
    
    l4 = tf.add(tf.matmul(l3,hidden_4_layer['weights']), hidden_4_layer['biases'])
    l4 = tf.nn.relu(l4)
    
    l5 = tf.add(tf.matmul(l4,hidden_5_layer['weights']), hidden_5_layer['biases'])
    l5 = tf.nn.relu(l5)
    
    l6 = tf.add(tf.matmul(l5,hidden_6_layer['weights']), hidden_6_layer['biases'])
    l6 = tf.nn.relu(l6)
    
    l7 = tf.add(tf.matmul(l6,hidden_7_layer['weights']), hidden_7_layer['biases'])
    l7 = tf.nn.relu(l7)
    
    l8 = tf.add(tf.matmul(l7,hidden_8_layer['weights']), hidden_8_layer['biases'])
    l8 = tf.nn.relu(l8)
    
    l9 = tf.add(tf.matmul(l8,hidden_9_layer['weights']), hidden_9_layer['biases'])
    l9 = tf.nn.relu(l9)
    
    l10 = tf.add(tf.matmul(l9,hidden_10_layer['weights']), hidden_10_layer['biases'])
    l10 = tf.nn.relu(l10)
    
    l11 = tf.add(tf.matmul(l10,hidden_11_layer['weights']), hidden_11_layer['biases'])
    l11 = tf.nn.relu(l11)

    output = tf.matmul(l11,output_layer['weights']) + output_layer['biases']

    return output

# %%
# Training Neural Network::
def train_neural_network(x):
    prediction = neural_network_model(x)
    cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y) )
    
    optimizer = tf.train.AdamOptimizer().minimize(cost)
    hm_epochs = 1000 # how many epochs
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        for epoch in range(hm_epochs):
            epoch_loss = 0
            for _ in range(int(mnist.train.num_examples/batch_size)):
                epoch_x, epoch_y = mnist.train.next_batch(batch_size)
                _, c = sess.run([optimizer, cost], feed_dict={x: epoch_x, y: epoch_y})
                epoch_loss += c

            print('Epoch', epoch, 'completed out of',hm_epochs,'loss:',epoch_loss)
            
            correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
            accuracy = tf.reduce_mean(tf.cast(correct, 'float'))
            print('Accuracy:',accuracy.eval({x:mnist.test.images, y:mnist.test.labels}))
            
        
        print('Final Accuracy:',accuracy.eval({x:mnist.test.images, y:mnist.test.labels}))

# %%
train_neural_network(x)
# Out:
# WARNING:tensorflow:From <ipython-input-8-430b7aee2d5b>:4: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# Epoch 0 completed out of 1000 loss: 979130337328.0
# Accuracy: 0.5127
# Epoch 1 completed out of 1000 loss: 122693462248.0
# Accuracy: 0.606
# Epoch 2 completed out of 1000 loss: 63868898772.0
# Accuracy: 0.6568
# Epoch 3 completed out of 1000 loss: 40029438802.0
# Accuracy: 0.6893
# Epoch 4 completed out of 1000 loss: 27506209382.0
# Accuracy: 0.7092
# Epoch 5 completed out of 1000 loss: 20231068032.0
# Accuracy: 0.7119
# Epoch 6 completed out of 1000 loss: 15112547732.5
# Accuracy: 0.7329
# Epoch 7 completed out of 1000 loss: 11611296373.0
# Accuracy: 0.7726
# Epoch 8 completed out of 1000 loss: 8976190742.0
# Accuracy: 0.762
# Epoch 9 completed out of 1000 loss: 7163916074.75
# Accuracy: 0.7744
# Epoch 10 completed out of 1000 loss: 5833038358.25
# Accuracy: 0.761
# Epoch 11 completed out of 1000 loss: 4647516481.125
# Accuracy: 0.7865
# Epoch 12 completed out of 1000 loss: 3861476372.75
# Accuracy: 0.8068
# Epoch 13 completed out of 1000 loss: 3267625453.25
# Accuracy: 0.8228
# Epoch 14 completed out of 1000 loss: 2788678394.375
# Accuracy: 0.8136
# Epoch 15 completed out of 1000 loss: 2404017420.125
# Accuracy: 0.8365
# Epoch 16 completed out of 1000 loss: 1943512554.8125
# Accuracy: 0.8163
# Epoch 17 completed out of 1000 loss: 1658971208.25
# Accuracy: 0.8364
# Epoch 18 completed out of 1000 loss: 1475745245.6875
# Accuracy: 0.8392
# Epoch 19 completed out of 1000 loss: 1283120465.5
# Accuracy: 0.8403
# Epoch 20 completed out of 1000 loss: 1074968466.34375
# Accuracy: 0.8562
# Epoch 21 completed out of 1000 loss: 999208005.375
# Accuracy: 0.8611
# Epoch 22 completed out of 1000 loss: 868616364.75
# Accuracy: 0.8547
# Epoch 23 completed out of 1000 loss: 723952335.2890625
# Accuracy: 0.8565
# Epoch 24 completed out of 1000 loss: 604359613.5429688
# Accuracy: 0.8608
# Epoch 25 completed out of 1000 loss: 559889005.3203125
# Accuracy: 0.8759
# Epoch 26 completed out of 1000 loss: 491229072.90625
# Accuracy: 0.8682
# Epoch 182 completed out of 1000 loss: 1206.9841593503952
# Accuracy: 0.1457
# Epoch 183 completed out of 1000 loss: 1207.6807923316956
# Accuracy: 0.1582
# Epoch 184 completed out of 1000 loss: 1207.9056951999664
# Accuracy: 0.1421
# Epoch 185 completed out of 1000 loss: 1208.5403108596802
# Accuracy: 0.1582
# Epoch 186 completed out of 1000 loss: 1207.859941482544
# Accuracy: 0.1427
# Epoch 187 completed out of 1000 loss: 1208.8517968654633
# Accuracy: 0.1582
# Epoch 188 completed out of 1000 loss: 1208.795387506485
# Accuracy: 0.1421
# Epoch 189 completed out of 1000 loss: 1209.472038269043
# Accuracy: 0.1428
# Epoch 190 completed out of 1000 loss: 1210.2497951984406
# Accuracy: 0.1405
# Epoch 191 completed out of 1000 loss: 1211.591153383255
# Accuracy: 0.1456
# Epoch 192 completed out of 1000 loss: 1212.049528837204
# Accuracy: 0.1473
# Epoch 193 completed out of 1000 loss: 1213.474615573883
# Accuracy: 0.1457
# Epoch 194 completed out of 1000 loss: 1214.2315146923065
# Accuracy: 0.1456
# Epoch 195 completed out of 1000 loss: 1216.6907444000244
# Accuracy: 0.1428
# Epoch 196 completed out of 1000 loss: 1214.9434844255447
# Accuracy: 0.1428
# Epoch 197 completed out of 1000 loss: 1216.4290580749512
# Accuracy: 0.1582
# Epoch 198 completed out of 1000 loss: 1218.6080918312073
# Accuracy: 0.1582
# Epoch 199 completed out of 1000 loss: 1218.9277262687683
# Accuracy: 0.1582
# Epoch 200 completed out of 1000 loss: 1218.8132178783417
# Accuracy: 0.1405
# Epoch 201 completed out of 1000 loss: 1220.1489276885986
# Accuracy: 0.1473
# Epoch 202 completed out of 1000 loss: 1218.7401268482208
# Accuracy: 0.1582
# Epoch 203 completed out of 1000 loss: 1218.9989442825317
# Accuracy: 0.1582
# Epoch 204 completed out of 1000 loss: 1219.8943564891815
# Accuracy: 0.1457
# Epoch 205 completed out of 1000 loss: 1219.6327562332153
# Accuracy: 0.1405
# Epoch 206 completed out of 1000 loss: 1219.795326948166
# Accuracy: 0.1456
# Epoch 207 completed out of 1000 loss: 1219.3494567871094
# Accuracy: 0.1456
# Epoch 208 completed out of 1000 loss: 1220.4837143421173
# Accuracy: 0.1457
# Epoch 209 completed out of 1000 loss: 1219.6273646354675
# Accuracy: 0.1456
# Epoch 210 completed out of 1000 loss: 1221.1802186965942
# Accuracy: 0.1457
# Epoch 211 completed out of 1000 loss: 1219.7562972307205
# Accuracy: 0.1428
# Epoch 212 completed out of 1000 loss: 1221.2708458900452
# Accuracy: 0.1428
# Epoch 213 completed out of 1000 loss: 1218.564587712288
# Accuracy: 0.1582
# Epoch 214 completed out of 1000 loss: 1219.4996581077576
# Accuracy: 0.1582
# Epoch 215 completed out of 1000 loss: 1219.884262561798
# Accuracy: 0.1405
# Epoch 216 completed out of 1000 loss: 1218.3835663795471
# Accuracy: 0.1457
# Epoch 217 completed out of 1000 loss: 1217.833678483963
# Accuracy: 0.1457
# Epoch 218 completed out of 1000 loss: 1219.6557250022888
# Accuracy: 0.1421
# Epoch 219 completed out of 1000 loss: 1217.4324264526367
# Accuracy: 0.1421
# Epoch 220 completed out of 1000 loss: 1219.3727589845657
# Accuracy: 0.1582
# Epoch 221 completed out of 1000 loss: 1219.4523545503616
# Accuracy: 0.1428
# Epoch 222 completed out of 1000 loss: 1219.213987827301
# Accuracy: 0.1405
# Epoch 223 completed out of 1000 loss: 1220.6021373271942
# Accuracy: 0.1582
# Epoch 224 completed out of 1000 loss: 1218.01957321167
# Accuracy: 0.1427
# Epoch 225 completed out of 1000 loss: 1219.9874062538147
# Accuracy: 0.1427
# Epoch 226 completed out of 1000 loss: 1218.8482656478882
# Accuracy: 0.1405
# Epoch 227 completed out of 1000 loss: 1217.610488653183
# Accuracy: 0.1405
# Epoch 228 completed out of 1000 loss: 1217.8596370220184
# Accuracy: 0.1456
# Epoch 229 completed out of 1000 loss: 1218.3235261440277
# Accuracy: 0.1456
# Epoch 230 completed out of 1000 loss: 1218.4071645736694
# Accuracy: 0.1473
# Epoch 231 completed out of 1000 loss: 1218.326767206192
# Accuracy: 0.1421
# Epoch 232 completed out of 1000 loss: 1217.6132559776306
# Accuracy: 0.1457
# Epoch 233 completed out of 1000 loss: 1219.4528625011444
# Accuracy: 0.1456
# Epoch 234 completed out of 1000 loss: 1219.7693626880646
# Accuracy: 0.1582
# Epoch 235 completed out of 1000 loss: 1217.3084993362427
# Accuracy: 0.1405
# Epoch 236 completed out of 1000 loss: 1217.1590626239777
# Accuracy: 0.1582
# Epoch 237 completed out of 1000 loss: 1218.0873064994812
# Accuracy: 0.1428
# Epoch 238 completed out of 1000 loss: 1217.2466886043549
# Accuracy: 0.1582
# Epoch 239 completed out of 1000 loss: 1217.9291853904724
# Accuracy: 0.1456
# Epoch 240 completed out of 1000 loss: 1218.156703710556
# Accuracy: 0.1582
# Epoch 241 completed out of 1000 loss: 1217.7373193502426
# Accuracy: 0.1405
# Epoch 242 completed out of 1000 loss: 1217.6885817050934
# Accuracy: 0.1456
# Epoch 243 completed out of 1000 loss: 1216.2588810920715
# Accuracy: 0.1456
# Epoch 244 completed out of 1000 loss: 1217.7815816402435
# Accuracy: 0.1428
# Epoch 245 completed out of 1000 loss: 1216.9696912765503
# Accuracy: 0.1582
# Epoch 246 completed out of 1000 loss: 1217.7031326293945
# Accuracy: 0.1428
# Epoch 247 completed out of 1000 loss: 1218.3507964611053
# Accuracy: 0.1405
# Epoch 248 completed out of 1000 loss: 1216.9626076221466
# Accuracy: 0.1457
# Epoch 249 completed out of 1000 loss: 1218.5858101844788
# Accuracy: 0.1582
# Epoch 250 completed out of 1000 loss: 1217.9032745361328
# Accuracy: 0.1473
# Epoch 251 completed out of 1000 loss: 1217.3260571956635
# Accuracy: 0.1582
# Epoch 252 completed out of 1000 loss: 1218.478376865387
# Accuracy: 0.1457
# Epoch 253 completed out of 1000 loss: 1217.3982572555542
# Accuracy: 0.1582
# Epoch 254 completed out of 1000 loss: 1216.4177868366241
# Accuracy: 0.1473
# Epoch 255 completed out of 1000 loss: 1216.417252421379
# Accuracy: 0.1405
# Epoch 256 completed out of 1000 loss: 1218.2954342365265
# Accuracy: 0.1428
# Epoch 257 completed out of 1000 loss: 1215.8928875923157
# Accuracy: 0.1428
# Epoch 258 completed out of 1000 loss: 1218.3772056102753
# Accuracy: 0.1405
# Epoch 259 completed out of 1000 loss: 1218.0851078033447
# Accuracy: 0.1427
# Epoch 260 completed out of 1000 loss: 1217.1244568824768
# Accuracy: 0.1473
# Epoch 261 completed out of 1000 loss: 1216.797818183899
# Accuracy: 0.1582
# Epoch 262 completed out of 1000 loss: 1216.0582649707794
# Accuracy: 0.1428
# Epoch 263 completed out of 1000 loss: 1215.4927434921265
# Accuracy: 0.1473
# Epoch 264 completed out of 1000 loss: 1218.7109310626984
# Accuracy: 0.1582
# Epoch 265 completed out of 1000 loss: 1216.3231647014618
# Accuracy: 0.1456
# Epoch 266 completed out of 1000 loss: 1216.0883622169495
# Accuracy: 0.1456
# Epoch 267 completed out of 1000 loss: 1217.3361802101135
# Accuracy: 0.1473
# Epoch 268 completed out of 1000 loss: 1216.2366465330124
# Accuracy: 0.1427
# Epoch 269 completed out of 1000 loss: 1215.2618117332458
# Accuracy: 0.1456
# Epoch 270 completed out of 1000 loss: 1216.3971395492554
# Accuracy: 0.1582
# Epoch 271 completed out of 1000 loss: 1215.7069643735886
# Accuracy: 0.1456
# Epoch 272 completed out of 1000 loss: 1215.9304447174072
# Accuracy: 0.1339
# Epoch 273 completed out of 1000 loss: 1216.1527000665665
# Accuracy: 0.1473
# Epoch 274 completed out of 1000 loss: 1216.1673424243927
# Accuracy: 0.1427
# Epoch 275 completed out of 1000 loss: 1217.522643327713
# Accuracy: 0.1473
# Epoch 276 completed out of 1000 loss: 1215.4593571424484
# Accuracy: 0.1473
# Epoch 277 completed out of 1000 loss: 1216.4854850769043
# Accuracy: 0.1582
# Epoch 278 completed out of 1000 loss: 1215.568499326706
# Accuracy: 0.1457
# Epoch 279 completed out of 1000 loss: 1215.2907390594482
# Accuracy: 0.1456
# Epoch 280 completed out of 1000 loss: 1217.504055738449
# Accuracy: 0.1427
# Epoch 281 completed out of 1000 loss: 1216.2841174602509
# Accuracy: 0.1457
# Epoch 282 completed out of 1000 loss: 1216.261598110199
# Accuracy: 0.1456
# Epoch 283 completed out of 1000 loss: 1215.613580942154
# Accuracy: 0.1456
# Epoch 284 completed out of 1000 loss: 1216.1738760471344
# Accuracy: 0.1473
# Epoch 285 completed out of 1000 loss: 1215.4044742584229
# Accuracy: 0.1582
# Epoch 286 completed out of 1000 loss: 1215.677402973175
# Accuracy: 0.1473
# Epoch 287 completed out of 1000 loss: 1216.5549330711365
# Accuracy: 0.1421
# Epoch 288 completed out of 1000 loss: 1216.1440879106522
# Accuracy: 0.1582
# Epoch 289 completed out of 1000 loss: 1215.4391201734543
# Accuracy: 0.1421
# Epoch 290 completed out of 1000 loss: 1215.9048340320587
# Accuracy: 0.1427
# Epoch 291 completed out of 1000 loss: 1215.9987280368805
# Accuracy: 0.1421
# Epoch 292 completed out of 1000 loss: 1214.849571466446
# Accuracy: 0.1421
# Epoch 293 completed out of 1000 loss: 1215.98006606102
# Accuracy: 0.1582
# Epoch 294 completed out of 1000 loss: 1214.3246586322784
# Accuracy: 0.1582
# Epoch 295 completed out of 1000 loss: 1215.0178949832916
# Accuracy: 0.1428
# Epoch 296 completed out of 1000 loss: 1214.7223789691925
# Accuracy: 0.1582
# Epoch 297 completed out of 1000 loss: 1215.6726117134094
# Accuracy: 0.1473
# Epoch 298 completed out of 1000 loss: 1215.2465274333954
# Accuracy: 0.1405
# Epoch 299 completed out of 1000 loss: 1213.9018545150757
# Accuracy: 0.1428
# Epoch 300 completed out of 1000 loss: 1213.7354843616486
# Accuracy: 0.1473
# Epoch 301 completed out of 1000 loss: 1215.60387301445
# Accuracy: 0.1456
# Epoch 302 completed out of 1000 loss: 1214.5230813026428
# Accuracy: 0.1456
# Epoch 303 completed out of 1000 loss: 1214.1772322654724
# Accuracy: 0.1421
# Epoch 304 completed out of 1000 loss: 1215.6696772575378
# Accuracy: 0.1473
# Epoch 305 completed out of 1000 loss: 1214.6586334705353
# Accuracy: 0.1427
# Epoch 306 completed out of 1000 loss: 1214.8872337341309
# Accuracy: 0.1473
# Epoch 307 completed out of 1000 loss: 1213.3675632476807
# Accuracy: 0.1473
# Epoch 308 completed out of 1000 loss: 1216.0267844200134
# Accuracy: 0.1473
# Epoch 309 completed out of 1000 loss: 1214.8854274749756
# Accuracy: 0.1473
# Epoch 310 completed out of 1000 loss: 1213.1418690681458
# Accuracy: 0.1421
# Epoch 311 completed out of 1000 loss: 1214.8868386745453
# Accuracy: 0.1582
# Epoch 312 completed out of 1000 loss: 1215.9594585895538
# Accuracy: 0.1339
# Epoch 313 completed out of 1000 loss: 1213.709068775177
# Accuracy: 0.1405
# Epoch 314 completed out of 1000 loss: 1214.7467665672302
# Accuracy: 0.1582
# Epoch 315 completed out of 1000 loss: 1213.737722158432
# Accuracy: 0.1473
# Epoch 316 completed out of 1000 loss: 1213.3479590415955
# Accuracy: 0.1582
# Epoch 317 completed out of 1000 loss: 1214.5298483371735
# Accuracy: 0.1421
# Epoch 318 completed out of 1000 loss: 1214.04878616333
# Accuracy: 0.1456
# Epoch 319 completed out of 1000 loss: 1214.6486876010895
# Accuracy: 0.1405
# Epoch 320 completed out of 1000 loss: 1213.0717396736145
# Accuracy: 0.1427
# Epoch 321 completed out of 1000 loss: 1213.6947176456451
# Accuracy: 0.1405
# Epoch 322 completed out of 1000 loss: 1215.223312139511
# Accuracy: 0.1582
# Epoch 323 completed out of 1000 loss: 1212.6034072637558
# Accuracy: 0.1405
# Epoch 324 completed out of 1000 loss: 1214.522872686386
# Accuracy: 0.1457
# Epoch 325 completed out of 1000 loss: 1214.1847310066223
# Accuracy: 0.1457
# Epoch 326 completed out of 1000 loss: 1214.1452467441559
# Accuracy: 0.1473
# Epoch 327 completed out of 1000 loss: 1214.88845205307
# Accuracy: 0.1457
# Epoch 328 completed out of 1000 loss: 1214.391800403595
# Accuracy: 0.1582
# Epoch 329 completed out of 1000 loss: 1212.6702139377594
# Accuracy: 0.1456
# Epoch 330 completed out of 1000 loss: 1212.5065762996674
# Accuracy: 0.1473
# Epoch 331 completed out of 1000 loss: 1214.2655494213104
# Accuracy: 0.1473
# Epoch 332 completed out of 1000 loss: 1213.2001938819885
# Accuracy: 0.1582
# Epoch 333 completed out of 1000 loss: 1215.0107278823853
# Accuracy: 0.1582
# Epoch 334 completed out of 1000 loss: 1212.8644375801086
# Accuracy: 0.1457
# Epoch 335 completed out of 1000 loss: 1214.4758169651031
# Accuracy: 0.1456
# Epoch 336 completed out of 1000 loss: 1213.6414029598236
# Accuracy: 0.1473
# Epoch 337 completed out of 1000 loss: 1213.6455354690552
# Accuracy: 0.1427
# Epoch 338 completed out of 1000 loss: 1213.4867279529572
# Accuracy: 0.1457
# Epoch 339 completed out of 1000 loss: 1212.9456915855408
# Accuracy: 0.1339
# Epoch 340 completed out of 1000 loss: 1214.1961600780487
# Accuracy: 0.1428
# Epoch 341 completed out of 1000 loss: 1213.3963364362717
# Accuracy: 0.1456
# Epoch 342 completed out of 1000 loss: 1211.4962663650513
# Accuracy: 0.1427
# Epoch 343 completed out of 1000 loss: 1212.0679318904877
# Accuracy: 0.1427
# Epoch 344 completed out of 1000 loss: 1212.940405011177
# Accuracy: 0.1582
# Epoch 345 completed out of 1000 loss: 1212.5113441944122
# Accuracy: 0.1582
# Epoch 346 completed out of 1000 loss: 1212.057226896286
# Accuracy: 0.1456
# Epoch 347 completed out of 1000 loss: 1213.5046223402023
# Accuracy: 0.1582
# Epoch 348 completed out of 1000 loss: 1212.132516860962
# Accuracy: 0.1582
# Epoch 349 completed out of 1000 loss: 1213.3920793533325
# Accuracy: 0.1405
# Epoch 350 completed out of 1000 loss: 1212.6201450824738
# Accuracy: 0.1456
# Epoch 351 completed out of 1000 loss: 1213.255755662918
# Accuracy: 0.1427
# Epoch 352 completed out of 1000 loss: 1212.5612580776215
# Accuracy: 0.1339
# Epoch 353 completed out of 1000 loss: 1212.8035066127777
# Accuracy: 0.1582
# Epoch 354 completed out of 1000 loss: 1210.9355833530426
# Accuracy: 0.1582
# Epoch 355 completed out of 1000 loss: 1212.4936261177063
# Accuracy: 0.1457
# Epoch 356 completed out of 1000 loss: 1211.8015648126602
# Accuracy: 0.1421
# Epoch 357 completed out of 1000 loss: 1211.4872846603394
# Accuracy: 0.1582
# Epoch 358 completed out of 1000 loss: 1212.945007801056
# Accuracy: 0.1473
# Epoch 359 completed out of 1000 loss: 1212.047449350357
# Accuracy: 0.1427
# Epoch 360 completed out of 1000 loss: 1213.0100803375244
# Accuracy: 0.1582
# Epoch 361 completed out of 1000 loss: 1211.8742566108704
# Accuracy: 0.1473
# Epoch 362 completed out of 1000 loss: 1212.1936905384064
# Accuracy: 0.1456
# Epoch 363 completed out of 1000 loss: 1211.9394512176514
# Accuracy: 0.1405
# Epoch 364 completed out of 1000 loss: 1211.1147146224976
# Accuracy: 0.1406
# Epoch 365 completed out of 1000 loss: 1212.2296555042267
# Accuracy: 0.1406
# Epoch 366 completed out of 1000 loss: 1211.2740219831467
# Accuracy: 0.1428
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e776a1e8e4f1> in <module>()
# ----> 1 train_neural_network(x)
#
# <ipython-input-8-430b7aee2d5b> in train_neural_network(x)
#      14             for _ in range(int(mnist.train.num_examples/batch_size)):
#      15                 epoch_x, epoch_y = mnist.train.next_batch(batch_size)
# ---> 16                 _, c = sess.run([optimizer, cost], feed_dict={x: epoch_x, y: epoch_y})
#      17                 epoch_loss += c
#      18
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
